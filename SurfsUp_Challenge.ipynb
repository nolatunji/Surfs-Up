# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June.
#  3. Convert the June temperatures to a list.
def june(start_date, end_date):
    june_results = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >= start_date).\
    filter(Measurement.date <= end_date).all()

    print(june_results)
june('2017-06-01','2017-06-30')
# Out:
# [('2017-06-01', 79.0), ('2017-06-02', 79.0), ('2017-06-03', 79.0), ('2017-06-04', 79.0), ('2017-06-05', 80.0), ('2017-06-06', 79.0), ('2017-06-07', 79.0), ('2017-06-08', 80.0), ('2017-06-09', 80.0), ('2017-06-10', 77.0), ('2017-06-11', 79.0), ('2017-06-12', 83.0), ('2017-06-13', 80.0), ('2017-06-14', 80.0), ('2017-06-15', 78.0), ('2017-06-16', 79.0), ('2017-06-17', 80.0), ('2017-06-18', 77.0), ('2017-06-19', 80.0), ('2017-06-20', 78.0), ('2017-06-21', 79.0), ('2017-06-22', 80.0), ('2017-06-23', 78.0), ('2017-06-24', 80.0), ('2017-06-25', 80.0), ('2017-06-26', 81.0), ('2017-06-27', 80.0), ('2017-06-28', 79.0), ('2017-06-29', 79.0), ('2017-06-30', 75.0), ('2017-06-01', 76.0), ('2017-06-02', 76.0), ('2017-06-03', 76.0), ('2017-06-04', 78.0), ('2017-06-05', 76.0), ('2017-06-06', 75.0), ('2017-06-07', 75.0), ('2017-06-08', 76.0), ('2017-06-09', 78.0), ('2017-06-10', 75.0), ('2017-06-11', 73.0), ('2017-06-12', 76.0), ('2017-06-13', 76.0), ('2017-06-14', 76.0), ('2017-06-15', 77.0), ('2017-
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
df = pd.DataFrame(june_results, columns =['date','temp'])
june_df = df[(df['date'] >= '2017-06-01') & (df['date'] <= '2017-06-30')]
june_df
# Out:
#            date  temp
# 0    2017-06-01  79.0
# 1    2017-06-02  79.0
# 2    2017-06-03  79.0
# 3    2017-06-04  79.0
# 4    2017-06-05  80.0
# ..          ...   ...
# 418  2017-06-26  79.0
# 419  2017-06-27  74.0
# 420  2017-06-28  74.0
# 421  2017-06-29  76.0
# 422  2017-06-30  75.0
#
# [191 rows x 2 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
df.describe()
# Out:
#              temp
# count  476.000000
# mean    78.042017
# std      2.905226
# min     69.000000
# 25%     76.000000
# 50%     78.000000
# 75%     80.000000
# max     87.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
# 7. Convert the December temperatures to a list.

dec_results = []
def dec(start_date, end_date):
    dec_results = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >= start_date).\
    filter(Measurement.date <= end_date).all()

    print(dec_results)
dec('2016-12-01','2016-12-31')
# Out:
# [('2016-12-01', 75.0), ('2016-12-02', 72.0), ('2016-12-03', 69.0), ('2016-12-04', 71.0), ('2016-12-05', 68.0), ('2016-12-06', 67.0), ('2016-12-07', 69.0), ('2016-12-08', 73.0), ('2016-12-09', 70.0), ('2016-12-10', 70.0), ('2016-12-11', 70.0), ('2016-12-12', 66.0), ('2016-12-13', 67.0), ('2016-12-14', 70.0), ('2016-12-15', 66.0), ('2016-12-16', 62.0), ('2016-12-17', 71.0), ('2016-12-18', 73.0), ('2016-12-19', 69.0), ('2016-12-20', 77.0), ('2016-12-21', 74.0), ('2016-12-22', 71.0), ('2016-12-23', 72.0), ('2016-12-24', 74.0), ('2016-12-25', 74.0), ('2016-12-26', 74.0), ('2016-12-27', 74.0), ('2016-12-28', 71.0), ('2016-12-29', 73.0), ('2016-12-30', 69.0), ('2016-12-31', 66.0), ('2016-12-01', 73.0), ('2016-12-02', 71.0), ('2016-12-03', 71.0), ('2016-12-04', 69.0), ('2016-12-05', 68.0), ('2016-12-06', 70.0), ('2016-12-07', 71.0), ('2016-12-08', 72.0), ('2016-12-09', 70.0), ('2016-12-10', 71.0), ('2016-12-11', 72.0), ('2016-12-12', 68.0), ('2016-12-13', 68.0), ('2016-12-14', 70.0), ('2016-
# ...

# %%
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
results = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >= prev_year).all()
year_df = pd.DataFrame(results, columns =['date','temp'])
year_df
# Out:
#             date  temp
# 0     2016-08-23  81.0
# 1     2016-08-24  79.0
# 2     2016-08-25  80.0
# 3     2016-08-26  79.0
# 4     2016-08-27  77.0
# ...          ...   ...
# 2225  2017-08-19  71.0
# 2226  2017-08-20  78.0
# 2227  2017-08-21  76.0
# 2228  2017-08-22  76.0
# 2229  2017-08-23  76.0
#
# [2230 rows x 2 columns]

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December.
dec_df = year_df[(year_df['date'] >= '2016-12-01') & (year_df['date'] < '2016-12-31')]
dec_df
# Out:
#             date  temp
# 100   2016-12-01  75.0
# 101   2016-12-02  72.0
# 102   2016-12-03  69.0
# 103   2016-12-04  71.0
# 104   2016-12-05  68.0
# ...          ...   ...
# 2002  2016-12-26  71.0
# 2003  2016-12-27  71.0
# 2004  2016-12-28  71.0
# 2005  2016-12-29  69.0
# 2006  2016-12-30  65.0
#
# [195 rows x 2 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame
dec_df.describe()
# Out:
#              temp
# count  195.000000
# mean    71.205128
# std      3.400875
# min     60.000000
# 25%     69.000000
# 50%     71.000000
# 75%     74.000000
# max     78.000000
